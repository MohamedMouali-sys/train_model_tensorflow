# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import numpy as np
import os
import cv2
from tqdm import tqdm
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
print("done")
# Out:
# 2025-06-01 04:06:57.533090: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748750817.732106      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748750817.789355      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# done

# %%
X = []
y = []

# Define folder paths and corresponding labels
paths_labels = {
    'Trans-cerebellum': 0,
    'Trans-thalamic': 1,
    'Trans-ventricular':2,
    'arachnoid-cyst': 3,
    'cerebellah-hypoplasia': 4,
    'encephalocele': 5,
    'mild-ventriculomegaly': 6,
    'moderate-ventriculomegaly': 7,
    'normal': 8,
    'severe-ventriculomegaly': 9,
}

for folder, label in paths_labels.items():
    path = f"/kaggle/input/dataset-kenza-v3-10/train/{folder}"
    os.chdir(path)
    for i in tqdm(os.listdir()):
        img = cv2.imread(i)
        img = cv2.resize(img, (224, 224))
        X.append(img)
        y.append(label)
for folder, label in paths_labels.items():
    path = f"/kaggle/input/dataset-kenza-v3-10/valid/{folder}"
    os.chdir(path)
    for i in tqdm(os.listdir()):
        img = cv2.imread(i)
        img = cv2.resize(img, (224, 224))
        X.append(img)
        y.append(label)

X = np.array(X) / 255.0  # Normalize
y = to_categorical(y, num_classes=10)
# Out:
# 100%|██████████| 940/940 [00:02<00:00, 341.68it/s]
# 100%|██████████| 2092/2092 [00:06<00:00, 330.95it/s]
# 100%|██████████| 794/794 [00:03<00:00, 233.90it/s]
# 100%|██████████| 112/112 [00:00<00:00, 255.96it/s]
# 100%|██████████| 103/103 [00:00<00:00, 248.17it/s]
# 100%|██████████| 113/113 [00:00<00:00, 257.09it/s]
# 100%|██████████| 195/195 [00:00<00:00, 242.13it/s]
# 100%|██████████| 258/258 [00:01<00:00, 252.50it/s]
# 100%|██████████| 227/227 [00:00<00:00, 258.92it/s]
# 100%|██████████| 94/94 [00:00<00:00, 256.64it/s]
# 100%|██████████| 120/120 [00:00<00:00, 254.34it/s]
# 100%|██████████| 317/317 [00:01<00:00, 260.37it/s]
# 100%|██████████| 110/110 [00:00<00:00, 246.69it/s]
# 100%|██████████| 14/14 [00:00<00:00, 260.13it/s]
# 100%|██████████| 11/11 [00:00<00:00, 278.40it/s]
# 100%|██████████| 18/18 [00:00<00:00, 255.18it/s]
# 100%|██████████| 27/27 [00:00<00:00, 199.43it/s]
# 100%|██████████| 30/30 [00:00<00:00, 241.73it/s]
# 100%|██████████| 31/31 [00:00<00:00, 265.86it/s]
# 100%|██████████| 13/13 [00:00<00:00, 260.94it/s]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
print("done")


datagen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.2,
    horizontal_flip=True
)
train_gen = datagen.flow(X_train, y_train, batch_size=32)
print("done")
# Out:
# done
# done

# %%
vgg = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze some layers
for layer in vgg.layers[:15]:
    layer.trainable = False
for layer in vgg.layers[15:]:
    layer.trainable = True

def create_model(bottom_model, num_classes):
    top_model = bottom_model.output
    top_model = GlobalAveragePooling2D()(top_model)
    top_model = Dense(1024, activation='relu')(top_model)
    top_model = BatchNormalization()(top_model)
    top_model = Dropout(0.5)(top_model)
    top_model = Dense(512, activation='relu')(top_model)
    top_model = BatchNormalization()(top_model)
    top_model = Dropout(0.3)(top_model)
    top_model = Dense(num_classes, activation='softmax')(top_model)
    return top_model

FC_Head = create_model(vgg, 10)
model = Model(inputs=vgg.input, outputs=FC_Head)



model.compile(optimizer=Adam(learning_rate=0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])
print("done")
# Out:
# done

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=3, verbose=1)
early_stop = EarlyStopping(monitor='val_accuracy', patience=10, restore_best_weights=True)
print("done")



history = model.fit(train_gen,
                    validation_data=(X_test, y_test),
                    epochs=50,
                    callbacks=[reduce_lr, early_stop])



model.save('/kaggle/working/maladie_classifier_v10.h5')
print("done")
# Out:
# done
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 52s 386ms/step - accuracy: 0.2735 - loss: 2.5694 - val_accuracy: 0.4658 - val_loss: 1.5191 - learning_rate: 1.0000e-04
# Epoch 2/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 40s 335ms/step - accuracy: 0.5175 - loss: 1.5985 - val_accuracy: 0.5606 - val_loss: 1.2087 - learning_rate: 1.0000e-04
# Epoch 3/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 40s 342ms/step - accuracy: 0.5978 - loss: 1.3179 - val_accuracy: 0.6151 - val_loss: 1.2117 - learning_rate: 1.0000e-04
# Epoch 4/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 40s 337ms/step - accuracy: 0.6326 - loss: 1.1754 - val_accuracy: 0.4539 - val_loss: 1.5210 - learning_rate: 1.0000e-04
# Epoch 5/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 39s 333ms/step - accuracy: 0.6726 - loss: 1.0364 - val_accuracy: 0.7186 - val_loss: 0.9232 - learning_rate: 1.0000e-04
# Epoch 6/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 40s 341ms/step - accuracy: 0.6982 - loss: 0.9046 - val_accuracy: 0.5903 - val_loss: 1.4906 - learning_rate: 1.0000e-04
# Epoch 7/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 38s 325ms/step - accuracy: 0.7218 - loss: 0.8375 - val_accuracy: 0.6981 - val_loss: 0.9772 - learning_rate: 1.0000e-04
# Epoch 8/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 39s 332ms/step - accuracy: 0.7269 - loss: 0.8233 - val_accuracy: 0.7256 - val_loss: 0.9512 - learning_rate: 1.0000e-04
# Epoch 9/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 39s 333ms/step - accuracy: 0.7730 - loss: 0.6883 - val_accuracy: 0.7272 - val_loss: 1.0352 - learning_rate: 1.0000e-04
# Epoch 10/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 39s 332ms/step - accuracy: 0.7888 - loss: 0.6399 - val_accuracy: 0.7580 - val_loss: 0.8241 - learning_rate: 1.0000e-04
# Epoch 11/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 39s 330ms/step - accuracy: 0.8084 - loss: 0.5497 - val_accuracy: 0.8140 - val_loss: 0.5506 - learning_rate: 1.0000e-04
# Epoch 12/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 38s 325ms/step - accuracy: 0.8111 - loss: 0.5436 - val_accuracy: 0.7989 - val_loss: 0.7082 - learning_rate: 1.0000e-04
# Epoch 13/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 39s 331ms/step - accuracy: 0.8200 - loss: 0.5317 - val_accuracy: 0.7887 - val_loss: 0.6970 - learning_rate: 1.0000e-04
# Epoch 14/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 39s 331ms/step - accuracy: 0.8289 - loss: 0.4876 - val_accuracy: 0.8399 - val_loss: 0.5312 - learning_rate: 1.0000e-04
# Epoch 15/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 39s 332ms/step - accuracy: 0.8202 - loss: 0.5217 - val_accuracy: 0.7827 - val_loss: 0.7088 - learning_rate: 1.0000e-04
# Epoch 16/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 39s 331ms/step - accuracy: 0.8527 - loss: 0.4003 - val_accuracy: 0.8329 - val_loss: 0.6096 - learning_rate: 1.0000e-04
# Epoch 17/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 39s 331ms/step - accuracy: 0.8583 - loss: 0.4074 - val_accuracy: 0.8528 - val_loss: 0.4811 - learning_rate: 1.0000e-04
# Epoch 18/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 39s 334ms/step - accuracy: 0.8657 - loss: 0.3596 - val_accuracy: 0.8453 - val_loss: 0.5697 - learning_rate: 1.0000e-04
# Epoch 19/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 39s 334ms/step - accuracy: 0.8808 - loss: 0.3569 - val_accuracy: 0.8350 - val_loss: 0.6108 - learning_rate: 1.0000e-04
# Epoch 20/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - accuracy: 0.8713 - loss: 0.3604
# Epoch 20: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 39s 332ms/step - accuracy: 0.8714 - loss: 0.3603 - val_accuracy: 0.8307 - val_loss: 0.5790 - learning_rate: 1.0000e-04
# Epoch 21/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 39s 330ms/step - accuracy: 0.9102 - loss: 0.2693 - val_accuracy: 0.8712 - val_loss: 0.3774 - learning_rate: 5.0000e-05
# Epoch 22/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 40s
50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step - accuracy: 0.9709 - loss: 0.0989
# Epoch 43: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 40s 342ms/step - accuracy: 0.9709 - loss: 0.0989 - val_accuracy: 0.8933 - val_loss: 0.4405 - learning_rate: 6.2500e-06
# Epoch 44/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 39s 333ms/step - accuracy: 0.9654 - loss: 0.1024 - val_accuracy: 0.8949 - val_loss: 0.4341 - learning_rate: 3.1250e-06
# Epoch 45/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 39s 331ms/step - accuracy: 0.9614 - loss: 0.1106 - val_accuracy: 0.8954 - val_loss: 0.4453 - learning_rate: 3.1250e-06
# Epoch 46/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - accuracy: 0.9675 - loss: 0.0944
# Epoch 46: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 40s 341ms/step - accuracy: 0.9675 - loss: 0.0944 - val_accuracy: 0.8927 - val_loss: 0.4367 - learning_rate: 3.1250e-06
# Epoch 47/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 40s 334ms/step - accuracy: 0.9662 - loss: 0.0910 - val_accuracy: 0.8970 - val_loss: 0.4445 - learning_rate: 1.5625e-06
# Epoch 48/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 40s 335ms/step - accuracy: 0.9650 - loss: 0.1055 - val_accuracy: 0.8943 - val_loss: 0.4457 - learning_rate: 1.5625e-06
# Epoch 49/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - accuracy: 0.9614 - loss: 0.1041
# Epoch 49: ReduceLROnPlateau reducing learning rate to 7.81249980263965e-07.
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 39s 333ms/step - accuracy: 0.9615 - loss: 0.1041 - val_accuracy: 0.8954 - val_loss: 0.4393 - learning_rate: 1.5625e-06
# Epoch 50/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 40s 336ms/step - accuracy: 0.9704 - loss: 0.0921 - val_accuracy: 0.8943 - val_loss: 0.4392 - learning_rate: 7.8125e-07
# done

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix

# ✅ Étape 1 : Prédictions
predictions = model.predict(X_test)
predicted_classes = np.argmax(predictions, axis=1)
true_classes = np.argmax(y_test, axis=1)

# ✅ Étape 2 : Rapport de classification
class_names = [
    'Transcerebellum',
    'Transthalamic',
    'Transventricular',
    'arachnoid-cyst',
    'cerebellah-hypoplasia',
    'encephalocele',
    'mild-ventriculomegaly',
    'moderate-ventriculomegaly',
    'normal',
    'severe-ventriculomegaly',
]

print("✅ Rapport de classification :\n")
print(classification_report(true_classes, predicted_classes, target_names=class_names))

# ✅ Étape 3 : Matrice de confusion
cm = confusion_matrix(true_classes, predicted_classes)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Prédit')
plt.ylabel('Vérité')
plt.title('Matrice de confusion')
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# ✅ Étape 4 : Courbes d’apprentissage
plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.title('Précision au fil des époques')
plt.xlabel('Épochs')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Validation')
plt.title('Perte au fil des époques')
plt.xlabel('Épochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# ✅ Étape 5 : Affichage de quelques exemples avec prédiction
plt.figure(figsize=(15, 15))
for i in range(25):
    idx = np.random.randint(0, len(X_test))
    img = X_test[idx]
    true_label = class_names[true_classes[idx]]
    pred_label = class_names[predicted_classes[idx]]
    color = 'green' if true_label == pred_label else 'red'
    
    plt.subplot(5, 5, i + 1)
    plt.imshow(img)
    plt.title(f"Vérité: {true_label}\nPrédit: {pred_label}", color=color, fontsize=9)
    plt.axis('off')

plt.tight_layout()
plt.show()

print("✅ Évaluation terminée avec succès.")
# Out:
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 91ms/step
# ✅ Rapport de classification :
#
#                            precision    recall  f1-score   support
#
#           Transcerebellum       0.92      0.96      0.94       376
#             Transthalamic       0.89      0.92      0.90       787
#          Transventricular       0.83      0.84      0.84       283
#            arachnoid-cyst       0.93      0.97      0.95        40
#     cerebellah-hypoplasia       0.95      1.00      0.97        35
#             encephalocele       0.93      0.90      0.91        41
#     mild-ventriculomegaly       0.98      0.95      0.97        65
# moderate-ventriculomegaly       0.96      0.92      0.94       103
#                    normal       1.00      0.41      0.58        85
#   severe-ventriculomegaly       0.91      0.97      0.94        40
#
#                  accuracy                           0.90      1855
#                 macro avg       0.93      0.89      0.89      1855
#              weighted avg       0.90      0.90      0.89      1855
# ✅ Évaluation terminée avec succès.
